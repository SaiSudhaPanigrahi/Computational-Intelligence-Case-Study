# %%
import os
print(os.listdir("../input"))
print(os.listdir("../input/flowershd5dataset/flowers-hd5/data/flowers/"))
print(os.listdir("../input/flowershd5words/"))
hdf5_fpath = "../input/flowershd5dataset/flowers-hd5/data/flowers/flowers.hdf5"
# Out:
# ['flowershd5words', 'flowershd5dataset']
# ['flowers.hdf5']
# ['flowers.hdf5.words']

# %%
#All imports are here

import io
import h5py
import argparse
import torch
import time
import pickle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from torch import nn
from datetime import timedelta
from torch.autograd import Variable
from torch.utils.data import DataLoader, Dataset
from sklearn.neighbors import NearestNeighbors

print("All libraries imported!")
# Out:
# All libraries imported!

# %%
#view contents in HDF5 files
f = h5py.File(hdf5_fpath)

#1. to know the categories in hdf5 file
print(list(f))
print("\nNo. of items in test = ",len(list(f['test'])))
print("\nNo. of items in train = ",len(list(f['train'])))
print("\nNo. of items in valid = ",len(list(f['valid'])))

#2. see what data is stored in each category
#print("\n\ntest = \n",list(f['test']))

#print("\n\ntrain = \n",list(f['train']))

#print("\n\nvalid = \n",list(f['valid']))
# Out:
# ['test', 'train', 'valid']
#
# No. of items in test =  5775
#
# No. of items in train =  29390
#
# No. of items in valid =  5780

# %% [markdown]
# **BOTTOM-UP approach ahead!!!**
#
# The code in the next cell follows bottom up execution flow, to understand which method is getting called when start from the last part i.e., **runtime.py** code snippet.

# %%
################ nn.py (NearestNeighbour) ###################

class NearestNeighbor:
    def __init__(self, dataset, source, cuda, ngf):
        self.dataset = dataset
        data = None
        representation = None
        labels = []
        embeddings = []
        path = ''
        data_path = path + 'source_{}_nn_data.pl'.format(source)
        labels_path = path + 'source_{}_nn_labels.pl'.format(source)
        nbrs_path = path + 'source_{}_nn.pl'.format(source)
        embeddings_path = path + 'source_{}_nn_embeddings.pl'.format(source)
        self.model = gan_factory.generator_factory('vae', ngf, False)
        if cuda:
            self.model = self.model.cuda()
        #self.model.load_state_dict(torch.load('./checkpoints/flowers_autoencoder/gen.pth'))

        if os.path.exists(data_path):
            print('start loading data for NN test {}'.format(data_path))
            data = pickle.load(open(data_path, 'rb'))
            labels = pickle.load(open(labels_path, 'rb'))
            nbrs = pickle.load(open(nbrs_path, 'rb'))
            embeddings = pickle.load(open(embeddings_path, 'rb'))
        else:
            print('start creating data for NN test {}'.format(data_path))
            for i, sample in enumerate(dataset):
                #print("**** iter i = ",i)
                if data is None:
                    data = sample['right_images'].numpy()
                    data_var = Variable(sample['right_images'].float(), volatile=True)
                    if cuda:
                        data_var = data_var.cuda()
                    representation = self.model.encoder_only(data_var).data.cpu().numpy()
                    labels = sample['txt']
                    embeddings = sample['right_embed']
                else:
                    data = np.append(data, sample['right_images'].numpy(), axis=0)
                    data_var = Variable(sample['right_images'].float(), volatile=True)
                    if cuda:
                        data_var = data_var.cuda()
                    representation = np.append(representation, self.model.encoder_only(data_var).data.cpu().numpy(),
                                               axis=0)
                    labels += sample['txt']
                    embeddings = np.append(embeddings, sample['right_embed'].numpy(), axis=0)
            nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree').fit(representation.reshape(-1, 228))
            pickle.dump(data, open(data_path, 'wb'))
            pickle.dump(labels, open(labels_path, 'wb'))
            pickle.dump(nbrs, open(nbrs_path, 'wb'))
            pickle.dump(embeddings, open(embeddings_path, 'wb'))
        print('finish loading data for NN test')
        self.data = data
        self.labels = labels
        self.nbrs = nbrs
        self.embeddings = embeddings

    def get_text(self, samples, limit=-1):
        text_results, _, _ = self.get_text_and_images_and_embedding(samples, limit)
        return text_results

    def get_text_and_images(self, samples, limit):
        text_results, image_results, _ = self.get_text_and_images_and_embedding(samples, limit)
        return text_results, image_results

    def get_text_and_images_and_embedding(self, samples, limit=-1):
        samples_embedding = self.model.encoder_only(samples).data.cpu().numpy().reshape(-1, 228)
        if limit != -1:
            samples_embedding = samples_embedding[:limit]
        distances, indices = self.nbrs.kneighbors(samples_embedding)
        text_results = [self.labels[index] for index in indices[:, 0]]
        image_results = [self.data[index] for index in indices[:, 0]]
        embedding_results = [self.embeddings[index] for index in indices[:, 0]]
        return text_results, image_results, embedding_results
    
################ nn.py (NearestNeighbour) ends here ###################

################ txt2image_dataset.py ###################

class Text2ImageDataset(Dataset):

    def __init__(self, datasetFile, transform=None, split=0):
        self.datasetFile = datasetFile
        self.transform = transform
        self.dataset = None
        self.dataset_keys = None
        self.split = 'train' if split == 0 else 'valid' if split == 1 else 'test'
        self.h5py2int = lambda x: int(np.array(x))

    def __len__(self):
        f = h5py.File(self.datasetFile, 'r')
        self.dataset_keys = [str(k) for k in f[self.split].keys()]
        length = len(f[self.split])
        f.close()

        return length

    def __getitem__(self, idx):
        if self.dataset is None:
            self.dataset = h5py.File(self.datasetFile, mode='r')
            self.dataset_keys = [str(k) for k in self.dataset[self.split].keys()]

        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]

        # pdb.set_trace()

        right_image = bytes(np.array(example['img']))
        right_embed = np.array(example['embeddings'], dtype=float)
        wrong_image = bytes(np.array(self.find_wrong_image(example['class'])))
        inter_embed = np.array(self.find_inter_embed())

        right_image = Image.open(io.BytesIO(right_image)).resize((64, 64))
        wrong_image = Image.open(io.BytesIO(wrong_image)).resize((64, 64))

        right_image = self.validate_image(right_image)
        wrong_image = self.validate_image(wrong_image)

        txt = np.array(example['txt']).astype(str)
        class_ = np.array(example['class']).astype(str)

        sample = {
                'right_images': torch.FloatTensor(right_image),
                'right_embed': torch.FloatTensor(right_embed),
                'wrong_images': torch.FloatTensor(wrong_image),
                'inter_embed': torch.FloatTensor(inter_embed),
                'txt': str(txt),
                'class': str(class_)
                 }

        sample['right_images'] = sample['right_images'].sub_(127.5).div_(127.5)
        sample['wrong_images'] =sample['wrong_images'].sub_(127.5).div_(127.5)

        return sample

    def find_wrong_image(self, category):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        _category = example['class']

        if _category != category:
            return example['img']

        return self.find_wrong_image(category)

    def find_inter_embed(self):
        idx = np.random.randint(len(self.dataset_keys))
        example_name = self.dataset_keys[idx]
        example = self.dataset[self.split][example_name]
        return example['embeddings']


    def validate_image(self, img):
        img = np.array(img, dtype=float)
        if len(img.shape) < 3:
            rgb = np.empty((64, 64, 3), dtype=np.float32)
            rgb[:, :, 0] = img
            rgb[:, :, 1] = img
            rgb[:, :, 2] = img
            img = rgb

        return img.transpose(2, 0, 1)

################ txt2image_dataset.py ends here ###################

################ utils.py ###################

class Concat_embed(nn.Module):
    def __init__(self, embed_dim, projected_embed_dim):
        super(Concat_embed, self).__init__()
        self.projection = nn.Sequential(nn.Linear(in_features=embed_dim, out_features=projected_embed_dim),
                                        nn.BatchNorm1d(num_features=projected_embed_dim),
                                        nn.LeakyReLU(negative_slope=0.2, inplace=True))

    def forward(self, inp, embed):
        projected_embed = self.projection(embed)
        replicated_embed = projected_embed.repeat(4, 4, 1, 1).permute(2, 3, 0, 1)
        hidden_concat = torch.cat([inp, replicated_embed], 1)

        return hidden_concat

class Utils(object):
    def __init__(self, cuda):
        self.is_cuda = cuda

    def cuda(self, variable):
        return variable.cuda() if self.is_cuda else variable

    @staticmethod
    def smooth_label(tensor, offset):
        return tensor + offset

    @staticmethod
    def save_checkpoint(netD, netG, dir_path, epoch):
        path = dir_path #os.path.join(dir_path, subdir_path)
        if not os.path.exists(path):
            os.makedirs(path)

        torch.save(netD.state_dict(), '{0}/disc_{1}.pth'.format(path, epoch))
        torch.save(netG.state_dict(), '{0}/gen_{1}.pth'.format(path, epoch))
        
    @staticmethod
    def weights_init(m):
        classname = m.__class__.__name__
        if classname.find('Conv') != -1:
            m.weight.data.normal_(0.0, 0.02)
        elif classname.find('BatchNorm') != -1:
            m.weight.data.normal_(1.0, 0.02)
            m.bias.data.fill_(0)

################ utils.py ends here ###################

################ vae.py ###################

class vae_encoder_generator(nn.Module):
    def __init__(self, ngf):
        super(vae_encoder_generator, self).__init__()
        self.vae_encoder = vae_encoder(ngf)
        self.vae_generator = vae_generator(ngf)

    def forward(self, inp):
        x = self.vae_encoder(inp)
        x = self.vae_generator(x)
        return x

    def generator_only(self, latent):
        return self.vae_generator(latent)

    def encoder_only(self, inp):
        return self.vae_encoder(inp.cuda())


class vae_generator(nn.Module):
    def __init__(self, ngf):
        super(vae_generator, self).__init__()
        self.image_size = 64
        self.num_channels = 3
        self.noise_dim = 100
        self.embed_dim = 1024
        self.projected_embed_dim = 128
        self.latent_dim = self.noise_dim + self.projected_embed_dim
        self.ngf = ngf

        # self.projection = nn.Sequential(nn.Linear(in_features=self.embed_dim, out_features=self.projected_embed_dim),
        #     nn.BatchNorm1d(num_features=self.projected_embed_dim), nn.LeakyReLU(negative_slope=0.2, inplace=True))

        # based on: https://github.com/pytorch/examples/blob/master/dcgan/main.py
        self.netG = nn.Sequential(
            nn.ConvTranspose2d(self.latent_dim, self.ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(self.ngf * 8),
            nn.ReLU(True), # state size. (ngf*8) x 4 x 4

            nn.ConvTranspose2d(self.ngf * 8, self.ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf * 4),
            nn.ReLU(True), # state size. (ngf*4) x 8 x 8

            nn.ConvTranspose2d(self.ngf * 4, self.ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf * 2),
            nn.ReLU(True), # state size. (ngf*2) x 16 x 16

            nn.ConvTranspose2d(self.ngf * 2, self.ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf),
            nn.ReLU(True),

            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d(self.ngf, self.num_channels, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (num_channels) x 64 x 64
        )

    def forward(self, latent_vector):
        # projected_embed = self.projection(embed_vector).unsqueeze(2).unsqueeze(3)
        # latent_vector = torch.cat([projected_embed, z], 1)
        latent_vector = latent_vector.view(-1, self.latent_dim, 1, 1)
        #print("**** latent_vector is cuda = ",latent_vector.cpu().is_cuda)
        output = self.netG(latent_vector.cpu())

        return output


class vae_encoder(nn.Module):
    def __init__(self, ngf):
        super(vae_encoder, self).__init__()
        self.image_size = 64
        self.num_channels = 3
        self.embed_dim = 1024
        self.noise_dim = 100
        self.projected_embed_dim = 128
        self.latent_dim = self.noise_dim + self.projected_embed_dim
        self.ngf = ngf

        self.projection = nn.Sequential(nn.Linear(in_features=self.embed_dim, out_features=self.projected_embed_dim),
            nn.BatchNorm1d(num_features=self.projected_embed_dim), nn.LeakyReLU(negative_slope=0.2, inplace=True))

        # based on: https://github.com/pytorch/examples/blob/master/dcgan/main.py
        self.netE = nn.Sequential(
            # state size. (num_channels) x 64 x 64
            nn.Conv2d(self.num_channels, self.ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf),
            nn.ReLU(True),

            # state size. (ngf) x 32 x 32
            nn.Conv2d(self.ngf, self.ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf * 2),
            nn.ReLU(True),

            # state size. (ngf*2) x 16 x 16
            nn.Conv2d(self.ngf * 2, self.ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf * 4),
            nn.ReLU(True),

            # state size. (ngf*4) x 8 x 8
            nn.Conv2d(self.ngf * 4, self.ngf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(self.ngf * 8),
            nn.ReLU(True),

            # state size. (ngf*8) x 4 x 4
            nn.Conv2d(self.ngf * 8, self.latent_dim, 4, 1, 0, bias=False),
            nn.Tanh()
        )

    def forward(self, images):
        output = self.netE(images)
        #print(output.is_cuda)
        return output


class vae_discriminator(nn.Module):
    def __init__(self, remove_noise):
        super(discriminator, self).__init__()
        self.image_size = 64
        self.num_channels = 128
        self.embed_dim = 1024
        if remove_noise:
            self.projected_embed_dim = 228
            self.noise_dim = 0
        else:
            self.projected_embed_dim = 128
            self.noise_dim = 100
        self.B_dim = 128
        self.C_dim = 16
        self.minibatch_discriminator = minibatch_discriminator(self.num_channels, self.B_dim, self.C_dim)
        #
        self.netD_1 = nn.Sequential(
            nn.Linear(self.projected_embed_dim + self.noise_dim, 228),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(228, 128),
            nn.LeakyReLU(0.2, inplace=True),
        )

        self.netD_2 = nn.Sequential(
            nn.Linear(128 + self.B_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, inp):
        x = inp.view(-1, self.projected_embed_dim + self.noise_dim)
        x = self.netD_1(x)
        x = self.minibatch_discriminator(x)
        x = self.netD_2(x)

        return x.view(-1)

################ vae.py ends here ###################

################ gan_cls.py ###################

class generator(nn.Module):
    def __init__(self, remove_noise, variational):
        super(generator, self).__init__()
        self.image_size = 64
        self.num_channels = 3
        self.embed_dim = 1024
        self.remove_noise = remove_noise
        if remove_noise:
            self.noise_dim = 0
            self.projected_embed_dim = 228
        else:
            self.noise_dim = 100
            self.projected_embed_dim = 128
        self.latent_dim = self.noise_dim + self.projected_embed_dim
        self.ngf = 64
        self.variational = variational
        self.mu = None
        self.sd = None

        self.projection = nn.Sequential(nn.Linear(in_features=self.embed_dim, out_features=self.projected_embed_dim),
            nn.BatchNorm1d(num_features=self.projected_embed_dim), nn.LeakyReLU(negative_slope=0.2, inplace=True))

        if variational:
            self.en_mu = nn.Conv2d(self.projected_embed_dim, self.projected_embed_dim, 1, 1, 0)
            self.en_sigma = nn.Conv2d(self.projected_embed_dim, self.projected_embed_dim, 1, 1, 0)
            self.softplus = nn.Softplus()
            self.en_mu.weight.data.normal_(0, 0.002)
            self.en_mu.bias.data.normal_(0, 0.002)
            self.en_sigma.weight.data.normal_(0, 0.002)
            self.en_sigma.bias.data.normal_(0, 0.002)

        # based on: https://github.com/pytorch/examples/blob/master/dcgan/main.py
        self.netG = nn.Sequential(nn.ConvTranspose2d(self.latent_dim, self.ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(self.ngf * 8), nn.ReLU(True), # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(self.ngf * 8, self.ngf * 4, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ngf * 4),
            nn.ReLU(True), # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d(self.ngf * 4, self.ngf * 2, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ngf * 2),
            nn.ReLU(True), # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d(self.ngf * 2, self.ngf, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ngf), nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d(self.ngf, self.num_channels, 4, 2, 1, bias=False), nn.Tanh()
            # state size. (num_channels) x 64 x 64
        )

    def forward(self, embed_vector, z, noise):
        return self.netG(self.encoder_only(embed_vector, z, noise))

    def encoder_only(self, embed_vector, z, noise):
        projected_embed = self.projection(embed_vector).unsqueeze(2).unsqueeze(3)
        if self.variational:
            self.mu = self.en_mu(projected_embed)
            self.sd = self.softplus(self.en_sigma(projected_embed))
            projected_embed = self.mu + self.sd.mul(noise)
        if self.remove_noise:
            latent_vector = projected_embed
        else:
            latent_vector = torch.cat([projected_embed, z], 1)
        return latent_vector

    def generator_only(self, latent_vector):
        return self.netG(latent_vector)


class discriminator(nn.Module):
    def __init__(self, remove_noise):
        super(discriminator, self).__init__()
        self.image_size = 64
        self.num_channels = 3
        self.embed_dim = 1024
        if remove_noise:
            self.projected_embed_dim = 228
        else:
            self.projected_embed_dim = 128
        self.ndf = 64
        self.B_dim = 128
        self.C_dim = 16

        self.netD_1 = nn.Sequential(# input is (nc) x 64 x 64
            nn.Conv2d(self.num_channels, self.ndf, 4, 2, 1, bias=False), nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(self.ndf, self.ndf * 2, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ndf * 2),
            nn.LeakyReLU(0.2, inplace=True), # state size. (ndf*2) x 16 x 16
            nn.Conv2d(self.ndf * 2, self.ndf * 4, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ndf * 4),
            nn.LeakyReLU(0.2, inplace=True), # state size. (ndf*4) x 8 x 8
            nn.Conv2d(self.ndf * 4, self.ndf * 8, 4, 2, 1, bias=False), nn.BatchNorm2d(self.ndf * 8),
            nn.LeakyReLU(0.2, inplace=True), )

        self.projector = Concat_embed(self.embed_dim, self.projected_embed_dim)

        self.netD_2 = nn.Sequential(# state size. (ndf*8) x 4 x 4
            nn.Conv2d(self.ndf * 8 + self.projected_embed_dim, 1, 4, 1, 0, bias=False), nn.Sigmoid())

    def forward(self, inp, embed):
        x_intermediate = self.netD_1(inp)
        x = self.projector(x_intermediate, embed)
        x = self.netD_2(x)

        return x.view(-1, 1).squeeze(1), x_intermediate

################ gan_cls.py ends here ###################

################ gan_factory.py ###################

class gan_factory(object):
    @staticmethod
    def generator_factory(type, ngf, remove_noise, variational=False):
        if type == 'gan':
            return generator(remove_noise, variational)
        elif type == 'vae':
            return vae_encoder_generator(ngf)

    @staticmethod
    def discriminator_factory(type, remove_noise):
        if type == 'gan':
            return discriminator(remove_noise)
        elif type == 'vae':
            return vae_discriminator(remove_noise)

################ gan_factory.py ends here ###################

################ trainer.py ###################

class Trainer(object):
    def __init__(self, type, dataset, split, lr, diter, vis_screen, save_path, l1_coef, l2_coef, pre_trained_gen,
                 pre_trained_disc, batch_size, num_workers, epochs, args, params_search=False):
        self.config = args
        self.cuda = torch.cuda.is_available()

        self.generator = gan_factory.generator_factory(type, args.ngf, args.remove_noise_2, args.variational)
        self.discriminator = gan_factory.discriminator_factory(type, args.remove_noise_2)

        self.target_generator = gan_factory.generator_factory(args.target_type, args.ngf, args.remove_noise_2)
        
        if self.cuda:
            self.generator = self.generator.cuda()
            self.discriminator = self.discriminator.cuda()

        if pre_trained_disc:
            print('loading {} from {}'.format('discriminator', pre_trained_disc))
            self.discriminator.load_state_dict(torch.load(pre_trained_disc))
        else:
            if not params_search:
                print('creating fresh params for {}'.format('discriminator'))
            self.discriminator.apply(Utils.weights_init)

        if pre_trained_gen:
            print('loading {} from {}'.format('generator', pre_trained_gen))
            self.generator.load_state_dict(torch.load(pre_trained_gen))
        else:
            if not params_search:
                print('creating fresh params for {}'.format('generator'))
            self.generator.apply(Utils.weights_init)

        if dataset == 'flowers_only':
            self.dataset = Text2ImageDataset(self.config.flowers_dataset_path, split=0)
            self.target_dataset = Text2ImageDataset(self.config.flowers_dataset_path, split=2)
        else:
            print('Dataset not supported, please select either birds, flowers or flowers_only.')
            exit()

        self.noise_dim = 100
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.lr = lr
        self.beta1 = 0.5
        self.num_epochs = epochs
        self.DITER = diter

        self.l1_coef = l1_coef
        self.l2_coef = l2_coef

        self.data_loader = DataLoader(self.dataset, batch_size=self.batch_size, shuffle=True,
                                      num_workers=self.num_workers)
        self.target_data_loader = DataLoader(self.target_dataset, batch_size=self.batch_size, shuffle=True,
                                             num_workers=self.num_workers)

        self.optimD = torch.optim.Adam(self.discriminator.parameters(), lr=self.lr, betas=(self.beta1, 0.999))
        self.optimG = torch.optim.Adam(self.generator.parameters(), lr=self.lr, betas=(self.beta1, 0.999))

        self.save_path = save_path
        self.type = type
        # self.h_el = args.h_el
        self.args = args
        if not params_search:
            self.checkpoints_path = 'tmp/'
            if not os.path.exists(self.checkpoints_path):
                os.makedirs(self.checkpoints_path)
            print("***Calling Nearest Neighbour***")
            self.nn = NearestNeighbor(self.target_data_loader, dataset, self.cuda, args.ngf)
        self.params_search = params_search
        
    def train(self, cls=False):
        print("*** Inside train() func ***")
        if self.type == 'gan':
            self._train_gan(cls)
        
    def _train_gan(self, cls):
        print("*** Inside _train_gan() func ***")
        criterion = nn.BCELoss()
        l2_loss = nn.MSELoss()
        l1_loss = nn.L1Loss()
        iteration = 0

        for epoch in range(self.num_epochs):
            for sample in self.data_loader:
                iteration += 1
                right_images = sample['right_images']
                right_embed = sample['right_embed']
                wrong_images = sample['wrong_images']

                right_images = Variable(right_images.float()).cuda()
                right_embed = Variable(right_embed.float()).cuda()
                wrong_images = Variable(wrong_images.float()).cuda()

                real_labels = torch.ones(right_images.size(0))
                fake_labels = torch.zeros(right_images.size(0))

                # ======== One sided label smoothing ==========
                # Helps preventing the discriminator from overpowering the
                # generator adding penalty when the discriminator is too confident
                # =============================================
                smoothed_real_labels = torch.FloatTensor(Utils.smooth_label(real_labels.numpy(), -0.1))

                real_labels = Variable(real_labels).cuda()
                smoothed_real_labels = Variable(smoothed_real_labels).cuda()
                fake_labels = Variable(fake_labels).cuda()

                # Train the discriminator
                self.discriminator.zero_grad()
                outputs, activation_real = self.discriminator(right_images, right_embed)
                real_loss = criterion(outputs, smoothed_real_labels)
                real_score = outputs

                if cls:
                    outputs, _ = self.discriminator(wrong_images, right_embed)
                    wrong_loss = criterion(outputs, fake_labels)
                    wrong_score = outputs

                if self.args.remove_noise:
                    noise = Variable(torch.zeros(right_images.size(0), self.noise_dim)).cuda()
                else:
                    noise = Variable(torch.randn(right_images.size(0), self.noise_dim)).cuda()
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise, noise)
                outputs, _ = self.discriminator(fake_images, right_embed)
                fake_loss = criterion(outputs, fake_labels)
                fake_score = outputs

                d_loss = real_loss + fake_loss

                if cls:
                    d_loss = d_loss + wrong_loss

                d_loss.backward()
                self.optimD.step()

                # Train the generator
                self.generator.zero_grad()
                if self.args.remove_noise:
                    noise = Variable(torch.zeros(right_images.size(0), self.noise_dim)).cuda()
                else:
                    noise = Variable(torch.randn(right_images.size(0), self.noise_dim)).cuda()
                noise = noise.view(noise.size(0), 100, 1, 1)
                fake_images = self.generator(right_embed, noise, noise)
                outputs, activation_fake = self.discriminator(fake_images, right_embed)
                _, activation_real = self.discriminator(right_images, right_embed)

                activation_fake = torch.mean(activation_fake, 0)
                activation_real = torch.mean(activation_real, 0)

                # ======= Generator Loss function============
                # This is a customized loss function, the first term is the regular cross entropy loss
                # The second term is feature matching loss, this measure the distance between the real and generated
                # images statistics by comparing intermediate layers activations
                # The third term is L1 distance between the generated and real images, this is helpful for the conditional case
                # because it links the embedding feature vector directly to certain pixel values.
                # ===========================================
                g_loss = criterion(outputs, real_labels) +\
                         self.l2_coef * l2_loss(activation_fake, activation_real.detach()) +\
                         self.l1_coef * l1_loss(fake_images, right_images)

                g_loss.backward()
                self.optimG.step()

                if iteration % 10 == 0:
                    print("Epoch: %d, d_loss= %f, g_loss= %f, ccaD(X)= %f, D(G(X))= %f" % (epoch, d_loss.data.cpu().mean(), g_loss.data.cpu().mean(), real_score.data.cpu().mean(), fake_score.data.cpu().mean()))

            if (epoch) % 10 == 0:
                Utils.save_checkpoint(self.discriminator, self.generator, self.save_path, epoch)
                
    def test(self):
        self.generator.eval()
        self.target_generator.eval()
        number_of_images = 2
        sample = next(iter(self.data_loader))
        all_nn_texts = []
        all_nn_images = []
        all_fake_sources = []
        all_transfers = []
        text = sample['txt']
        right_images = sample['right_images']
        right_embed = sample['right_embed']
        for i in range(number_of_images):
            right_images_v = Variable(right_images.float(), volatile=True)
            right_embed_v = Variable(right_embed.float(), volatile=True)
            if self.args.remove_noise:
                noise = Variable(torch.zeros(right_images_v.size(0), self.noise_dim), volatile=True)
            else:
                noise = Variable(torch.randn(right_images_v.size(0), self.noise_dim), volatile=True)
            if self.cuda:
                right_embed_v = right_embed_v.cuda()
                noise = noise.cuda()

            noise = noise.view(noise.size(0), self.noise_dim, 1, 1)
            #print("right_embed_v type = ",type(right_embed_v),"noise = ",type(noise))
            fake_target = self.target_generator.generator_only(self.generator.encoder_only(right_embed_v, noise, noise))
            all_transfers.append(fake_target)
            fake_source = self.generator(right_embed_v, noise,noise)
            all_fake_sources.append(fake_source)
            
            fake_source = fake_source.cuda()
            print("fake_source shape: ",fake_source.detach().shape)
            print("text description: ",text[0])
            plt.imshow(fake_source[0].cpu().detach().permute(1, 2, 0))
            plt.show()

            nn_text, nn_images = self.nn.get_text_and_images(fake_target, -1)
            all_nn_texts.append(nn_text)
            all_nn_images.append(nn_images)
            
        for i, sentence in enumerate(text):
            nn_sentences = [sents[i] for sents in all_nn_texts]
            print("\ncombined text: ",i,"original sentence: ",sentence,"nn_sentences: ",nn_sentences)

        for i, image in enumerate(right_images):
            nn_images = [imgs[i] for imgs in all_nn_images]
            fake_source_images = [imgs[i].data.cpu().numpy() for imgs in all_fake_sources]
            transfers_images = [imgs[i].data.cpu().numpy() for imgs in all_transfers]
            image_tile = np.tile(image, (len(nn_images), 1, 1, 1))
            #self.logger.draw_test(image_tile, fake_source_images, transfers_images, nn_images, 'image {}'.format(i))
        print("*** end of testing ***")
   
################ trainer.py ends here ###################

################ runtime.py ###################
class Struct:
    def __init__(self, **entries):
        self.__dict__.update(entries)
        
parser = argparse.ArgumentParser()
params = dict()

params['type']='gan' #change this if you want to train any other gan
params['target_type']='vae'
params['lr']=0.0002
params['l1_coef']=50
params['l2_coef']=100
params['diter']=5
params['cls']=False
params['save_path']='tmp/'
params['inference']=False
params['target_train']=False
params['dataset']='flowers_only'
params['split']=0
params['batch_size']=128
params['num_workers']=1
params['ngf']=64
params['epochs']=1
params['remove_noise']=False
params['remove_noise_2']=False
params['variational']=False
params['vis_screen']=False
params['pre_trained_disc']=False
params['pre_trained_gen']=False
params['flowers_dataset_path']="../input/flowershd5dataset/flowers-hd5/data/flowers/flowers.hdf5"

args = Struct(**params) #Convert nested Python dict to object

trainer = Trainer(type=args.type, dataset=args.dataset, split=args.split, lr=args.lr, diter=args.diter,
                  vis_screen=args.vis_screen, save_path=args.save_path, l1_coef=args.l1_coef, 
                  l2_coef=args.l2_coef,pre_trained_disc=args.pre_trained_disc, 
                  pre_trained_gen=args.pre_trained_gen, batch_size=args.batch_size, 
                  num_workers=args.num_workers, epochs=args.epochs, args=args)

start_time = time.time()

if not args.inference:
    if args.target_train:
        trainer.target_train(args.cls)
    else:
        trainer.train(args.cls)
print("*** Calling test() ***")
trainer.test()

elapsed = str(timedelta(seconds=int(time.time() - start_time)))
print('Running {} took {}'.format("GAN-CLS", elapsed))

################ runtime.py ends here ###################
# Out:
# creating fresh params for discriminator
# creating fresh params for generator
# ***Calling Nearest Neighbour***
# start creating data for NN test source_flowers_only_nn_data.pl
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:32: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:40: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# finish loading data for NN test
# *** Inside train() func ***
# *** Inside _train_gan() func ***
# Epoch: 0, d_loss= 1.617161, g_loss= 35.504299, ccaD(X)= 0.428376, D(G(X))= 0.162539
# Epoch: 0, d_loss= 1.639528, g_loss= 33.890709, ccaD(X)= 0.394034, D(G(X))= 0.213867
# Epoch: 0, d_loss= 1.208030, g_loss= 33.206276, ccaD(X)= 0.664270, D(G(X))= 0.367615
# Epoch: 0, d_loss= 0.835486, g_loss= 30.288124, ccaD(X)= 0.593913, D(G(X))= 0.089171
# Epoch: 0, d_loss= 0.901833, g_loss= 26.471893, ccaD(X)= 0.542795, D(G(X))= 0.139539
# Epoch: 0, d_loss= 1.716739, g_loss= 25.997036, ccaD(X)= 0.338796, D(G(X))= 0.125863
# Epoch: 0, d_loss= 1.044263, g_loss= 27.833376, ccaD(X)= 0.814645, D(G(X))= 0.420500
# Epoch: 0, d_loss= 1.022458, g_loss= 29.410378, ccaD(X)= 0.821439, D(G(X))= 0.440046
# Epoch: 0, d_loss= 1.032008, g_loss= 26.780315, ccaD(X)= 0.556112, D(G(X))= 0.237622
# Epoch: 0, d_loss= 1.050292, g_loss= 28.582623, ccaD(X)= 0.716289, D(G(X))= 0.406929
# Epoch: 0, d_loss= 1.035152, g_loss= 27.508963, ccaD(X)= 0.554217, D(G(X))= 0.268199
# Epoch: 0, d_loss= 0.933393, g_loss= 26.275297, ccaD(X)= 0.700116, D(G(X))= 0.329541
# Epoch: 0, d_loss= 1.092577, g_loss= 26.899422, ccaD(X)= 0.752566, D(G(X))= 0.440997
# Epoch: 0, d_loss= 1.571303, g_loss= 24.043045, ccaD(X)= 0.364085, D(G(X))= 0.150246
# Epoch: 0, d_loss= 1.038471, g_loss= 25.097860, ccaD(X)= 0.511049, D(G(X))= 0.225393
# Epoch: 0, d_loss= 1.704869, g_loss= 25.310659, ccaD(X)= 0.270516, D(G(X))= 0.112830
# Epoch: 0, d_loss= 1.356664, g_loss= 26.895859, ccaD(X)= 0.766957, D(G(X))= 0.569183
# Epoch: 0, d_loss= 0.901856, g_loss= 24.485556, ccaD(X)= 0.545891, D(G(X))= 0.160084
# Epoch: 0, d_loss= 0.963830, g_loss= 25.557617, ccaD(X)= 0.672123, D(G(X))= 0.316010
# Epoch: 0, d_loss= 1.143644, g_loss= 25.351900, ccaD(X)= 0.530868, D(G(X))= 0.300865
# Epoch: 0, d_loss= 1.266995, g_loss= 24.569130, ccaD(X)= 0.418892, D(G(X))= 0.225673
# Epoch: 0, d_loss= 0.860298, g_loss= 25.317335, ccaD(X)= 0.682792, D(G(X))= 0.279989
# Epoch: 0, d_loss= 0.899064, g_loss= 26.668068, ccaD(X)= 0.741012, D(G(X))= 0.348640
# *** Calling test() ***
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:672: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:673: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:677: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# fake_source shape:  torch.Size([128, 3, 64, 64])
# text description:  this flower has wide pink petals that create a funnel shaped blossom with a thick pink pistil at the center.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:672: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:673: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:677: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# fake_source shape:  torch.Size([128, 3, 64, 64])
# text description:  this flower has wide pink petals that create a funnel shaped blossom with a thick pink pistil at the center.
# combined text:  0 original sentence:  this flower has wide pink petals that create a funnel shaped blossom with a thick pink pistil at the center.
#  nn_sentences:  ['this flower has large and very smooth white petals with rounded edges.\n', 'the petals on this flower are white with a yellow pistil.\n']
#
# combined text:  1 original sentence:  this flower has a heart shaped pink petal with a waxy surface and deep veins along with an orange pistil.
#  nn_sentences:  ['this flower has a spiked green bulb topped with a hairlike fringe of purple petals.\n', 'this flower has yellow and stringy petals that form a circle\n']
#
# combined text:  2 original sentence:  a large red flower with a gold and brown center.
#  nn_sentences:  ['this flower has a dome-like configuration of very skinny pink petals.\n', 'the flower has light pink petals with pink veins and white stamens.\n']
#
# combined text:  3 original sentence:  this flower has petals that are yellow and has an orange center
#  nn_sentences:  ['this flower has soft and smooth pink petals with accents of white and yellow.\n', 'this flower has petals that are white with a long style\n']
#
# combined text:  4 original sentence:  these blooms are trumpet shaped and bright pink with purple at the center.
#  nn_sentences:  ['a flower with very large, broad white petals and red and green central stamen\n', 'this flower has petals that are white and has a yellow center\n']
#
# combined text:  5 original sentence:  there are several clusters of orange flowers around reddish seeds.
#  nn_sentences:  ['this flower has petals that are yellow with short steman\n', 'the flower has petals that are yellow with green pedicel.\n']
#
# combined text:  6 original sentence:  a flower with long and wide petals that are white, yellow, and purple.
#  nn_sentences:  ['this flower has large white and purple petals with a light green pedicel.\n', 'curved pink stamen are surrounded by oval shaped pink and yellow petals that have subtle brown spots and lines on the innermost petals.\n']
#
# combined text:  7 original sentence:  this flower has layers of tapered peach colored petals and a pale yellow center.
#  nn_sentences:  ['this unique yellow flower has long finger like petals surrounding the large inner stamen area.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  8 original sentence:  this flower has petals that are white and has green lines
#  nn_sentences:  ['this flower has purple-pink petals with yellow inner areas of the petal and dark red stripes on some of the petals.\n', 'this white flower has a heart shaped petal and a yellow orange pistil.\n']
#
# combined text:  9 original sentence:  this flower has large fan shaped pink petals with white highlights and some with darker spots.
#  nn_sentences:  ['the flower has a smooth purple petal with a green pedicel\n', 'the petals on this flower are white with a yellow pistil.\n']
#
# combined text:  10 original sentence:  this flower is orange and yellow in color, with petals that are oval shaped.
#  nn_sentences:  ['this flower is green and pink in color, with petals that are spikey.\n', 'flower with hair thin purple petals above a large spiky sepal.\n']
#
# combined text:  11 original sentence:  a dark purple petal flower with a yellow center and black stripes.
#  nn_sentences:  ['this flower is white in color, and has a single large rounded petal.\n', 'this flower is yellow in color, with petals that are very skinny.\n']
#
# combined text:  12 original sentence:  this flower has petals that are yellow with red patches
#  nn_sentences:  ['this is a small flower with blue petals and green ovary.\n', 'a large pistil with golden yellow anthers within a white bell shaped singular pedal.\n']
#
# combined text:  13 original sentence:  this flower has numerous tightly curled petals that are mostly pink, but tinged with a bit of a coral color, the sepals are deep green.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'this flower has very short green pointed sepals underneath a single layer of yellow oblong petals in a ring.\n']
#
# combined text:  14 original sentence:  this flower has light blue petals that have pink lines on them
#  nn_sentences:  ['the petals of the flower is purple with a green sepal that it is sitting on.\n', 'this flower has petals that are pink and has yellow lines\n']
#
# combined text:  15 original sentence:  a flower that is all pink with pink filaments as well
#  nn_sentences:  ['the petals on this flower are link with a long stigma\n', 'this flower is pink and white in color, and has petals that are oddly shaped.\n']
#
# combined text:  16 original sentence:  this flower has long pointed pink petals and they are stacked on top of one another
#  nn_sentences:  ['this flower is made up of four large greenish petals with plum stripes.\n', 'the flower has petals that are orange with brown spots and red stamen.\n']
#
# combined text:  17 original sentence:  this flower is pink in color, and has petals that are curled up and oddly shaped.
#  nn_sentences:  ['this flower has large and very smooth white petals with rounded edges.\n', 'this flower has petals that are pink and has yellow lines\n']
#
# combined text:  18 original sentence:  the petals of the flower are pink in color and have a center that is yellow in color.
#  nn_sentences:  ['this is a large, white flower with large petals and yellow stamen.\n', 'the petals of the flower are are a vibrant white color, and the stamens are a light green color.\n']
#
# combined text:  19 original sentence:  this flower is pink and purple in color, with petals that are oddly shaped.
#  nn_sentences:  ['the flower has many close together soft round yellow petals.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  20 original sentence:  these magnificent purple-petaled flowers feature numerous yellow stamen.
#  nn_sentences:  ['the flower has a large purple petal with yellow anther and filaments\n', 'this flower has petals that are yellow and are bunched together\n']
#
# combined text:  21 original sentence:  the leaves are green and brod, the petals are alternatly shapd and are yellow in color
#  nn_sentences:  ['the petals are rounded and are light pink with dark maroon veins.\n', 'this flower has pale pink petals with veins and a white center.\n']
#
# combined text:  22 original sentence:  this flower has large white petals with pink ruffling on the edges and yellow center accents.
#  nn_sentences:  ['the yellow petals look like sticks with small yellow round stamen in the middle.\n', 'the petal has a slightly drooping blue petal with a white pollen tube\n']
#
# combined text:  23 original sentence:  this flower has petals that are pink and has yellow shading
#  nn_sentences:  ['this flower is purple in color, and has petals that are very skinny.\n', 'this flower has long white petals and no visible outer stamen\n']
#
# combined text:  24 original sentence:  this flower has a globe-like shape made up of many yellow petals.
#  nn_sentences:  ['the flowers and pedals of this flower look like a butterfly and they are spread out.\n', 'the petals on this flower are purple with purple stamen.\n']
#
# combined text:  25 original sentence:  this flower has small, ribbon like yellow petals with white tips.
#  nn_sentences:  ['this flower has petals that are pink with purple lines\n', 'this flower has yellow center and a fringe of very thin yellow hair-like petals.\n']
#
# combined text:  26 original sentence:  a peachy red flower it has a lot of petals bunched up again teach other.
#  nn_sentences:  ['a stamen that tapers between yellow and pale green is contained within a white and bell shaped seamless petal.\n', 'the flower has white petals with light pink veins, it has yellow filaments, and anthers\n']
#
# combined text:  27 original sentence:  the flower has blue petals with a purple streak leading to a white center
#  nn_sentences:  ['the flower has maroon petals and a yellow and black spotted stamen, with lavender colored filaments.\n', 'this flower has many purple petals arranged in a flat, disk shape with a brown center.\n']
#
# combined text:  28 original sentence:  this flower has yellow petals as well as a white stamen.
#  nn_sentences:  ['the flower has many close together soft round yellow petals.\n', 'this flower is green and pink in color, with petals that are spikey.\n']
#
# combined text:  29 original sentence:  this flower has petals that are white with purple filaments and green anthers.
#  nn_sentences:  ['the leaves are long and dark green, and there are two overlapping rows of pink flower petals with green points surrounding a pistil with green stigma and pink style.\n', 'this flower has petals that are white and has a yellow center\n']
#
# combined text:  30 original sentence:  the flower is pink with petals that are soft, smooth and has dense layers in the centre and has loose layers in the outer region
#  nn_sentences:  ['this flower has pointy green petals as its main feature\n', 'this flower has petals that are white and is bell shaped\n']
#
# combined text:  31 original sentence:  this light yellow flower has star shaped petals atop a green receptacle.
#  nn_sentences:  ['the leaves are long and dark green, and there are two overlapping rows of pink flower petals with green points surrounding a pistil with green stigma and pink style.\n', 'this flower has long and pointy red petals and a group of white stamen in the cener\n']
#
# combined text:  32 original sentence:  the sepals are green,the petals are overlapping and are light pink
#  nn_sentences:  ['this flower has white petals as well as a white pistil.\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  33 original sentence:  this flower is red in color, with petals that are wavy.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  34 original sentence:  a flower with light pink petals and green leaves.
#  nn_sentences:  ['the flower has a smooth purple petal with a green pedicel\n', 'the petals on this flower are yellow with yellow stamen\n']
#
# combined text:  35 original sentence:  a flower that has three bright pinkish purple petals.
#  nn_sentences:  ['this flower has petals that are purple with patches of white and green stamen\n', 'this flower has soft and smooth pink petals with accents of white and yellow.\n']
#
# combined text:  36 original sentence:  this bright white flower has heart-shaped petals with a burnt orange center and short stamen.
#  nn_sentences:  ['this flower is red and yellow in color, with petals that are small.\n', 'each part of the flower, including the petals, pistil, stamen, sepals are all varying shades of dark to light green.\n']
#
# combined text:  37 original sentence:  this flower has pale purple petals with deep purple veins coming out of the center towards the tips.
#  nn_sentences:  ['the petals of the flowers are curly and spotted with violet circles and it has long stamen\n', 'the petals on this flower are link with a long stigma\n']
#
# combined text:  38 original sentence:  this flower has a large funnel shaped petal that has uneven edges and is colored white.
#  nn_sentences:  ['this flower is pink and purple in color, and has petals that are spotted.\n', 'the petals on this flower are white with a yellow pistil.\n']
#
# combined text:  39 original sentence:  this flower is white and pink in color, with petals that are pointed on the tips.
#  nn_sentences:  ['this flower has thin blue and white petals as its main feature.\n', 'this flower has petals that are white and has yellow stamen\n']
#
# combined text:  40 original sentence:  a flower that has mostly white petals, with a purple/pink star pattern and a light yellow center
#  nn_sentences:  ['this flower has petals that are narrow and golden with a green pedicel.\n', 'the petals of this flower are purple with a long stigma\n']
#
# combined text:  41 original sentence:  this flower has long yellow petals with a red stripe down the center surrounding the yellow stamen.
#  nn_sentences:  ['this flower has a thick green stem and petals of deep indigo with delicate veins.\n', 'this flower is white and red in color, with petals that are multi colored.\n']
#
# combined text:  42 original sentence:  this flower has full, large petals, that are red/pink near the ovary and fade to a bright pink toward the edges.
#  nn_sentences:  ['this petal has gorgeous purple petals and a long green pedicel\n', 'this petal has gorgeous purple petals and a long green pedicel\n']
#
# combined text:  43 original sentence:  this flower has petals that are orange and has yellow edges
#  nn_sentences:  ['the petals of this flower are magenta with a long stigma\n', 'this flower has soft and smooth pink petals with accents of white and yellow.\n']
#
# combined text:  44 original sentence:  this coral flower has several rings of petals which are arrayed about its center.
#  nn_sentences:  ['this flower has many purple, hair-like petals, growing out a spikey green sepal\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  45 original sentence:  this flower has a bright yellow center and several large red petals.
#  nn_sentences:  ['a large pistil with golden yellow anthers within a white bell shaped singular pedal.\n', 'the petals on this flower are pink with yellow stamen.\n']
#
# combined text:  46 original sentence:  this flower is white and blue in color, with petals that are oval shaped.
#  nn_sentences:  ['the flower has petals that are yellow with green pedicel.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  47 original sentence:  this flower has white petals with deep green veins and a green ovule.
#  nn_sentences:  ['this flower has purple petals as well as a green pedicel.\n', 'this flower has pale pink petals with veins and a white center.\n']
#
# combined text:  48 original sentence:  a flower with pink and white petals curled up on each other.
#  nn_sentences:  ['the leaves are long and dark green, and there are two overlapping rows of pink flower petals with green points surrounding a pistil with green stigma and pink style.\n', 'this flower has petals that are red and are very small\n']
#
# combined text:  49 original sentence:  this small flower has bright yellow petals, stamen, and anthers.
#  nn_sentences:  ['the flower has long white petals with thin red dots that are long.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  50 original sentence:  this blood red flower has a heart shaped petal and a white and yellow pistil.
#  nn_sentences:  ['this flower has white anther and pink petals as its main features\n', 'this flower has long and pointy red petals and a group of white stamen in the cener\n']
#
# combined text:  51 original sentence:  the flower is red in color and the stamen are green in color.
#  nn_sentences:  ['this flower has petals that are white with a long style\n', 'this flower has petals that are narrow and golden with a green pedicel.\n']
#
# combined text:  52 original sentence:  this flower has petals that are orange and has yellow shading
#  nn_sentences:  ['the petals of the flowers are curly and spotted with violet circles and it has long stamen\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  53 original sentence:  this flower has a drooping head and wide pink petals with thick veins.
#  nn_sentences:  ['this flower is blue in color, with petals that have veins.\n', 'this flower is characterized by its brittle yellow petal appearance as well as its yellow pistil at the center.\n']
#
# combined text:  54 original sentence:  this flower is red in color, and has petals that are oval shaped.
#  nn_sentences:  ['this flower is green and pink in color, with petals that are pointed.\n', 'this flower has many petals that are white shading into a greenish yellow.\n']
#
# combined text:  55 original sentence:  this white-petaled flower has thin, long petals arranged in a circular shape around a bright yellow pistil.
#  nn_sentences:  ['this flower has petals that are white and has yellow shading\n', 'the petals of this flower are magenta with a long stigma\n']
#
# combined text:  56 original sentence:  this flower has large white petals with yellow leading to the center.
#  nn_sentences:  ['this flower has a spiky round green bulb topped with a thick pink fringe.\n', 'the petals of the flowers are curly and spotted with violet circles and it has long stamen\n']
#
# combined text:  57 original sentence:  this flower has petals that are orange and has a flowery stigma
#  nn_sentences:  ['the flower has long white petals with thin red dots that are long.\n', 'a flower with light yellow and green petals coming out of a brown pedicel.\n']
#
# combined text:  58 original sentence:  this flower has petals that are white with yellow stamen
#  nn_sentences:  ['this flower has purple petals and a thorny green pedicel\n', 'this flower has a spiked green bulb topped with a hairlike fringe of purple petals.\n']
#
# combined text:  59 original sentence:  this flower has bright red petals with irregular white markings.
#  nn_sentences:  ['this flower has petals that are white with pink shading\n', 'this flower has white petals as well as a white pistil.\n']
#
# combined text:  60 original sentence:  the bright pink petals have dark pink spots and ruffled edges and the stamen have brown anther.
#  nn_sentences:  ['petals are light brown in color,stamens are white in color\n', 'this flower has petals that are white and has a yellow shading\n']
#
# combined text:  61 original sentence:  flower is white with purlple dots and the petal is made like a stick
#  nn_sentences:  ['the flower has a smooth purple petal with a green pedicel\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  62 original sentence:  this flower has petals that are pink with a light green center and red stamen.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'this flower has very short green pointed sepals underneath a single layer of yellow oblong petals in a ring.\n']
#
# combined text:  63 original sentence:  this flower has petals that are overlapping with a burgundy layer under a layer of white petals with a burgundy spot.
#  nn_sentences:  ['this flower has petals that are yellow with black lines\n', 'this flower has white petals as well as a white pistil.\n']
#
# combined text:  64 original sentence:  shiny, waxy petals with identical yellow stamen with rectangular anthers.
#  nn_sentences:  ['this flower has petals that are purple and has stringy stamen\n', 'a flower with no visible petals and purple pistils in the center.\n']
#
# combined text:  65 original sentence:  a hot pink flowers with several wavy petals and a white pollen tube with lots of light yellow stamen in the middle.
#  nn_sentences:  ['this particular flower has petals that are long and white with a yellow center\n', 'this flower has large and very smooth white petals with rounded edges.\n']
#
# combined text:  66 original sentence:  this flower has yellow petals with red patches in the center
#  nn_sentences:  ['this flower has long prominent filaments with dark anthers rising out of bright orange petals with purple spots.\n', 'this flower is pink in color, and has petals that are very skinny.\n']
#
# combined text:  67 original sentence:  this flower has small light yellow petals with darker yellow near the base.
#  nn_sentences:  ['this flower has a spiked green bulb topped with a hairlike fringe of purple petals.\n', 'this flower features pinkish-white petals with leaves of green along the outside.\n']
#
# combined text:  68 original sentence:  this flower has thick, white petals and long, white stamen
#  nn_sentences:  ['this flower has petals folded tightly inside each other of a light green color and black spots at some edeges.\n', 'this flower has petals that are yellow with short steman\n']
#
# combined text:  69 original sentence:  this flower is pink in color, and has petals that are leaf like.
#  nn_sentences:  ['this is a large, white flower with large petals and yellow stamen.\n', 'this flower has petals that are white and has a yellow center\n']
#
# combined text:  70 original sentence:  this flower has a few light yellow lower petals with stripes near the center and purple upper petals.
#  nn_sentences:  ['this flower has petals that are white and has a yellow center\n', 'this flower has pink and white petals and a large, half dome shaped stamen.\n']
#
# combined text:  71 original sentence:  this flower has petals that are pink and have many layers
#  nn_sentences:  ['this flower is white and pink in color, with petals that are striped.\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  72 original sentence:  a flower with open tubular pink petals, green sepals, and green pedicel
#  nn_sentences:  ['the flower has a smooth purple petal with a green pedicel\n', 'this flower has soft and smooth pink petals with accents of white and yellow.\n']
#
# combined text:  73 original sentence:  this flower has white petals and a yellow color leading to the pistil.
#  nn_sentences:  ['this flower has pale pink petals with veins and a white center.\n', 'the petals of this flower are magenta with a long stigma\n']
#
# combined text:  74 original sentence:  the petals of the flower are white in color and have thin white filaments.
#  nn_sentences:  ['this flower has several large white petals with rounded edges, accented with deep purple lines.\n', 'this flower is purple and white in color, with petals that are multi colored.\n']
#
# combined text:  75 original sentence:  this flower has long purple petals bent back from a center with many long fringes of purple and an elaborate center.
#  nn_sentences:  ['this flower has petals that are red and are very small\n', "the flower has a very thick set of orange petals with it's inner parts a light yellow color.\n"]
#
# combined text:  76 original sentence:  medium sized, yellow-red petals and brown anthers.
#  nn_sentences:  ['this flower has long and pointy red petals and a group of white stamen in the cener\n', 'the petals on this flower are purple with yellow stamen\n']
#
# combined text:  77 original sentence:  the petals are red and smooth, and the stamens are red as well.
#  nn_sentences:  ['this flower has soft and smooth pink petals with accents of white and yellow.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  78 original sentence:  this flower has petals that are purple with a yellow stamen
#  nn_sentences:  ['the flower has many close together soft round yellow petals.\n', 'this flower is green and pink in color, with petals that are spikey.\n']
#
# combined text:  79 original sentence:  this flower is purple in color, with petals that are ruffled and uneven.
#  nn_sentences:  ['this flower has many purple, hair-like petals, growing out a spikey green sepal\n', 'this orange flower has about 10 wing like petals with sharp long blue green leaves.\n']
#
# combined text:  80 original sentence:  the petals on this flower are a bright pinkish color.
#  nn_sentences:  ['this flower has petals that are purple with bits of white\n', 'this flower is pink and yellow in color, and has petals that are striped and oval shaped.\n']
#
# combined text:  81 original sentence:  the flower has small yellow petals that are near wilted and red.
#  nn_sentences:  ['a flower with no visible petals and lavender pistils protruding from the top.\n', 'this particular flower has petals that are long and white with a yellow center\n']
#
# combined text:  82 original sentence:  this flower has fan shaped white petals that surround yellow stamen.
#  nn_sentences:  ['this flower is pink and red in color, with petals that are drooping downward.\n', 'this flower has a dome-like configuration of very skinny pink petals.\n']
#
# combined text:  83 original sentence:  the flower has several boat shaped purple petals, and pale yellow stamen
#  nn_sentences:  ['this flower has petals that are purple with bits of white\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  84 original sentence:  this flower has petals that are purple and are very thin
#  nn_sentences:  ['this is a large, white flower with large petals and yellow stamen.\n', 'this flower has soft and smooth pink petals with accents of white and yellow.\n']
#
# combined text:  85 original sentence:  this flower has small, overlapping petals which are a pale and waxy red hue.
#  nn_sentences:  ['this flower has petals that are white and has a yellow center\n', 'this is a large, white flower with large petals and yellow stamen.\n']
#
# combined text:  86 original sentence:  this is an all white flower with a yellow stigma and a green pedicel.
#  nn_sentences:  ['this purple flower has small curled petals and green sepal.\n', 'this flower is purple and green in color, with petals that are pointed.\n']
#
# combined text:  87 original sentence:  this is an orange flower with spots of red on the petals and white stigma.
#  nn_sentences:  ['this flower is purple and green in color, with petals that are pointed.\n', 'this flower has long white stamen and large light purple petals that are whiter at their base.\n']
#
# combined text:  88 original sentence:  the flower has one row of very light purple petals with a row of thin dark purple petals.
#  nn_sentences:  ['the flower has skinny pointed purple petals, stamen, and pistils.\n', 'this orange flower has the simple row of petals dotted with brown inside and has the prominent red stamens at the center\n']
#
# combined text:  89 original sentence:  this is a strange flower with white petals and green stamen.
#  nn_sentences:  ['this flower has petals that are purple and has a yellow style\n', 'a flower with no visible petals and purple pistils in the center.\n']
#
# combined text:  90 original sentence:  layers of bright yellow, thin petals surround a large, prominent circle of dark brown stamen.
#  nn_sentences:  ['this is a purple flower with no obvious petals, but the purple parts are long and narrow.\n', 'this flower has petals that are pink with purple spots\n']
#
# combined text:  91 original sentence:  this flower has petals that are purple on the tips and turn white closer to the pistil.
#  nn_sentences:  ['this flower has petals that are pink with yellowpatches\n', 'this flower is purple and green in color, with petals that are pointed.\n']
#
# combined text:  92 original sentence:  this flower is pink and white in color, with horn shaped petals.
#  nn_sentences:  ['this flower is orange and green in color, with petals that are skinny and pointed.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  93 original sentence:  this flower is white, blue and purple in color, with white oval shaped petals.
#  nn_sentences:  ['the petals of this flower are magenta with a long stigma\n', 'this flower has soft and smooth pink petals with accents of white and yellow.\n']
#
# combined text:  94 original sentence:  this flower is red, white, and yellow in color, with one large shiny petal.
#  nn_sentences:  ['this flower has petals that are white and has a yellow center\n', 'this flower has petals that are pink and has dark spots\n']
#
# combined text:  95 original sentence:  orange and red petals white middle green leaves
#  nn_sentences:  ['this flower has petals that are white and has a yellow center\n', 'this flower is pink and white in color, with petals that are pointed upward.\n']
#
# combined text:  96 original sentence:  the beautiful big yellow flower has petals that are soft, smooth and has dark red stripes along the length of petals and also a bunch of yellow stamens are fixed in the centre
#  nn_sentences:  ['the flower has long white petals with thin red dots that are long.\n', 'this flower is orange in color, with long pointed petals.\n']
#
# combined text:  97 original sentence:  a flower with a connected petals that are white.
#  nn_sentences:  ['this flower has pale pink petals with veins and a white center.\n', 'this flower has petals that are yellow and are folded together\n']
#
# combined text:  98 original sentence:  this flower is white, purple, and yellow in color, and has petals that are striped near the ovary.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'the needle shaped leaves are smlaer with rounded large petal purple in color,with white anthers\n']
#
# combined text:  99 original sentence:  this flower has pointed green sepals and multicolored petals in varying shades of orange and yellow.
#  nn_sentences:  ['this flower has petals that are purple and are very thin\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  100 original sentence:  this flower has four fan shaped yellow petals with red highlights and a white stamen.
#  nn_sentences:  ['this flower has pointy green petals as its main feature\n', 'this flower has petals that are white and has a yellow center\n']
#
# combined text:  101 original sentence:  the petals of this flower are white with a long stigma
#  nn_sentences:  ['a flower with orange petals with black spots accompanied by black anther filaments.\n', 'this flower is orange in color, with long pointed petals.\n']
#
# combined text:  102 original sentence:  this flower has petals that are white and has yellow stamen
#  nn_sentences:  ['this flower has several large white petals with rounded edges, accented with deep purple lines.\n', 'this flower has white furry petals with many green pointed ovaries.\n']
#
# combined text:  103 original sentence:  the flower is layered and is red in color with yellow blooms and green leaves.
#  nn_sentences:  ['the petals of the flowers are curly and spotted with violet circles and it has long stamen\n', 'this flower has petals that are pink and bell shaped\n']
#
# combined text:  104 original sentence:  the flower has petals that are shaped like a trumpit and purple petals with purple spots.
#  nn_sentences:  ['this flower has yellow and stringy petals that form a circle\n', 'the petals on this flower are white with a yellow pistil.\n']
#
# combined text:  105 original sentence:  the flower has many large velvety red petals surrounding newly formed buds.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'this flower is pink and white in color, with petals that are wavy.\n']
#
# combined text:  106 original sentence:  the flower is white with fused petal and has small bunch of stamen in the centre
#  nn_sentences:  ['the petals are pink and white in color and have yellow detail with a thin maroon stalk.\n', 'this flower has a dome-like configuration of very skinny pink petals.\n']
#
# combined text:  107 original sentence:  the flower has petals that are dark pink with pink stigma.
#  nn_sentences:  ['a one petal flower that is white with a cluster of yellow anther filaments in the center.\n', 'a thick green pedical supports the bright yellow petals of this flower.\n']
#
# combined text:  108 original sentence:  this flower has petals that are yellow with a yellow style
#  nn_sentences:  ['this flower has pale pink petals with veins and a white center.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  109 original sentence:  this flower has petals that are dark pink with white centers and white stigma.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'this flower has a spiky round green bulb topped with a thick pink fringe.\n']
#
# combined text:  110 original sentence:  the petals of this flower are pink with a short stigma
#  nn_sentences:  ['the flower has petals that are yellow with green pedicel.\n', 'the flower has a smooth purple petal with a green pedicel\n']
#
# combined text:  111 original sentence:  this reddish pink flower has rounded pedals and a green pedicel.
#  nn_sentences:  ['this flower has petals that are white and has a yellow center\n', 'this flower has a light pink petal and it curves upwards towards the middle\n']
#
# combined text:  112 original sentence:  bell shaped petals on this flower with lavender on the outiside and white and magenta speckled on inside.
#  nn_sentences:  ['this flower has a green ovary, yellow stamen, a white pistil and light pink petals.\n', 'this flower has white petals with blue tips on it and no outer stamen on it\n']
#
# combined text:  113 original sentence:  this flower has white petals with jagged edges and pink stripes down the center of them.
#  nn_sentences:  ['this flower has wide and very smooth white petals and a yellow mouth.\n', 'the petals of this flower are white, the pistil is yellow and the pedicel is green\n']
#
# combined text:  114 original sentence:  a flower with light pink and yellow petals and a pink pistil.
#  nn_sentences:  ['this flower has pale pink petals with veins and a white center.\n', 'this flower has white petals as well as a white pistil.\n']
#
# combined text:  115 original sentence:  a flower with long and wide petals that are yellow with orange spots.
#  nn_sentences:  ['this flower has yellow and stringy petals that form a circle\n', 'this flower has long and very skinny bright yellow petals in a ray formation.\n']
#
# combined text:  116 original sentence:  this flower has petals that are pink and has white tips
#  nn_sentences:  ['this flower is white and pink in color, with petals that are striped.\n', 'this flower has wide and very smooth white petals and a yellow mouth.\n']
#
# combined text:  117 original sentence:  this flower has many yellow petals with a solid black pistil.
#  nn_sentences:  ['the flower has deep purple petals with a light green pedicel.\n', 'this flower has petals that are green and has purple stamen\n']
#
# combined text:  118 original sentence:  this white and yellow flower has five petals with a green pedicel.
#  nn_sentences:  ['this flower is pink in color, and has petals that are very skinny.\n', 'the leaves are long and dark green, and there are two overlapping rows of pink flower petals with green points surrounding a pistil with green stigma and pink style.\n']
#
# combined text:  119 original sentence:  this is a flower with white petals and yellow anthers.
#  nn_sentences:  ['a thick green pedical supports the bright yellow petals of this flower.\n', 'the petals on this flower are purple with yellow stamen\n']
#
# combined text:  120 original sentence:  this flower has five large, smooth white petals with slightly pointed tips and bright yellow centers.
#  nn_sentences:  ['the flower has soft petals that are white and yellow in color.\n', 'curved pink stamen are surrounded by oval shaped pink and yellow petals that have subtle brown spots and lines on the innermost petals.\n']
#
# combined text:  121 original sentence:  this flower has layers of upturned, tapered petals in white and pale pink.
#  nn_sentences:  ['the flower has many long peach colored pollen tubes.\n', 'this flower is white and pink in color, with petals that are spotted.\n']
#
# combined text:  122 original sentence:  this flower has orange pistil and pink petals as its main features
#  nn_sentences:  ['this flower has soft and smooth pink petals with accents of white and yellow.\n', 'this flower is white and pink in color, with petals that are spotted.\n']
#
# combined text:  123 original sentence:  this flower has coral red petals with yellow tips, and a large red ovule with yellow and red stamen.
#  nn_sentences:  ['the flowrs has larger pistill with a larger yellow in color stamen hanging outside\n', 'exotic looking deep purple and white petal with smaller and thinner sepals and whitish towards the ovule with no visible pistil\n']
#
# combined text:  124 original sentence:  this flower has petals that are pink and has purple dots
#  nn_sentences:  ['this flower has blue and white petals with brown stamen in the center of it.\n', 'this flower has petals that are pink and has a yellow center\n']
#
# combined text:  125 original sentence:  the flower is made up of layers of pink and purple blooms that have dark speckles.
#  nn_sentences:  ['this flower is yellow in color, with petals that are very skinny.\n', 'this flower is white and purple in color, with petals that are bell shaped.\n']
#
# combined text:  126 original sentence:  this flower has bright yellow petals in a wavy arrangement and with crinkled edges.
#  nn_sentences:  ['this flower is green and pink in color, with petals that are spikey.\n', 'this flower has petals that are yellow and are folded together\n']
#
# combined text:  127 original sentence:  this flower is yellow and red in color with small stamen that are white.
#  nn_sentences:  ['the flower has a smooth purple petal with a green pedicel\n', 'the petals are white and light green colored and are ruffled on the edges.\n']
# *** end of testing ***
# Running GAN-CLS took 0:06:40
